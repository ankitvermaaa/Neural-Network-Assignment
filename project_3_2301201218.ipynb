# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitvermaaa/Neural-Network-Assignment/blob/main/project_3_2301201218.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ANN (Iris Dataset + Graphs)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

# %%
data = load_iris()
X = data.data
y = data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model_ann = keras.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(4,)),
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dense(3, activation='softmax')
])

model_ann.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_ann = model_ann.fit(
    X_train, y_train,
    epochs=20,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.5417 - loss: 1.1399 - val_accuracy: 0.3333 - val_loss: 1.1831
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5500 - loss: 1.1203 - val_accuracy: 0.3333 - val_loss: 1.1676
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5500 - loss: 1.1011 - val_accuracy: 0.3667 - val_loss: 1.1521
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5667 - loss: 1.0820 - val_accuracy: 0.3667 - val_loss: 1.1380
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5750 - loss: 1.0633 - val_accuracy: 0.3667 - val_loss: 1.1239
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5833 - loss: 1.0454 - val_accuracy: 0.3667 - val_loss: 1.1099
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5833 - loss: 1.0277 - val_accuracy: 0.3667 - val_loss: 1.0964
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5750 - loss: 1.0100 - val_accuracy: 0.4000 - val_loss: 1.0836
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5750 - loss: 0.9929 - val_accuracy: 0.4000 - val_loss: 1.0714
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5750 - loss: 0.9750 - val_accuracy: 0.4000 - val_loss: 1.0594
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5750 - loss: 0.9572 - val_accuracy: 0.4000 - val_loss: 1.0475
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5833 - loss: 0.9389 - val_accuracy: 0.4333 - val_loss: 1.0356
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5833 - loss: 0.9213 - val_accuracy: 0.4000 - val_loss: 1.0235
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5667 - loss: 0.9028 - val_accuracy: 0.3667 - val_loss: 1.0108
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5750 - loss: 0.8843 - val_accuracy: 0.5000 - val_loss: 0.9976
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6500 - loss: 0.8659 - val_accuracy: 0.6667 - val_loss: 0.9839
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6917 - loss: 0.8473 - val_accuracy: 0.6667 - val_loss: 0.9701
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7167 - loss: 0.8288 - val_accuracy: 0.6667 - val_loss: 0.9559
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7167 - loss: 0.8100 - val_accuracy: 0.7000 - val_loss: 0.9412
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7417 - loss: 0.7917 - val_accuracy: 0.7333 - val_loss: 0.9265

# %%
# Accuracy graph
plt.figure()
plt.plot(history_ann.history['accuracy'])
plt.plot(history_ann.history['val_accuracy'])
plt.title("ANN Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# Loss graph
plt.figure()
plt.plot(history_ann.history['loss'])
plt.plot(history_ann.history['val_loss'])
plt.title("ANN Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model_ann.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.title("ANN Confusion Matrix")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %% [markdown]
# CNN (MNIST + Visualization)

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.figure()
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')
plt.show()

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

X_train = X_train.reshape(-1,28,28,1)
X_test = X_test.reshape(-1,28,28,1)

# %%
model_cnn = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28,28,1)), # Explicitly define Input layer
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model_cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_cnn = model_cnn.fit(
    X_train, y_train,
    epochs=5,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 66s 33ms/step - accuracy: 0.9534 - loss: 0.1522 - val_accuracy: 0.9845 - val_loss: 0.0487
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 59s 31ms/step - accuracy: 0.9849 - loss: 0.0496 - val_accuracy: 0.9861 - val_loss: 0.0381
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - accuracy: 0.9896 - loss: 0.0341 - val_accuracy: 0.9893 - val_loss: 0.0368
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 56s 30ms/step - accuracy: 0.9920 - loss: 0.0252 - val_accuracy: 0.9902 - val_loss: 0.0324
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 76s 27ms/step - accuracy: 0.9939 - loss: 0.0190 - val_accuracy: 0.9918 - val_loss: 0.0246

# %%
# Accuracy
plt.figure()
plt.plot(history_cnn.history['accuracy'])
plt.plot(history_cnn.history['val_accuracy'])
plt.title("CNN Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# Loss
plt.figure()
plt.plot(history_cnn.history['loss'])
plt.plot(history_cnn.history['val_loss'])
plt.title("CNN Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# %%
predictions = model_cnn.predict(X_test)

plt.figure()
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title(f"Pred: {np.argmax(predictions[i])}")
    plt.axis('off')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
